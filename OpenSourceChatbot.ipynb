# %%
import torch

if torch.cuda.is_available():
    print("GPU is connected!")
    print(f"GPU Name: {torch.cuda.get_device_name(0)}")
else:
    print("No GPU connected.")
# Out:
# GPU is connected!
# GPU Name: Tesla T4

# %% [markdown]
# Using

# %%
# !pip install torch -q
# !pip install transformers -q
# !pip install numpy -q
# !pip install langchain -q
# !pip install langchain_community -q
# !pip install langchain-chroma -q
# !pip install sentence_transformers -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 51.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 61.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 kB 35.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 4.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 5.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 628.3/628.3 kB 22.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 72.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 6.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.6/278.6 kB 23.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 80.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.2/93.2 kB 9.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 107.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.6/166.6 kB 15.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.3/64.3 kB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.1/118.1 kB 10.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.8/54.8 kB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 kB 6.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.1/442.1 kB 33.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.7/319.7 kB 26.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 104.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 443.8/443.8 kB 34.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.2/168.2 kB 15.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.1 MB/s eta 0:00:00
#   Building wheel for pypika (pyproject.toml) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.17.1 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 5.29.1 which is incompatible.
# tensorflow-metadata 1.13.1 requires protobuf<5,>=3.20.3, but you have protobuf 5.29.1 which is incompatible.

# %% [markdown]
# ## **Initialize HuggingFace LLM**

# %%
from langchain_community.llms import HuggingFaceHub

llm = HuggingFaceHub(
    repo_id="mistralai/Mistral-7B-v0.1",
    model_kwargs={"temperature":0.1, "max_length":500},
    huggingfacehub_api_token="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"
)
# Out:
# <ipython-input-3-4d6129ff70cb>:3: LangChainDeprecationWarning: The class `HuggingFaceHub` was deprecated in LangChain 0.0.21 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEndpoint``.
#   llm = HuggingFaceHub(

# %% [markdown]
# ## **Initialize Embedding model**

# %%
from langchain.embeddings import HuggingFaceEmbeddings

embedding_model = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-mpnet-base-v2",
)
# Out:
# <ipython-input-4-b34c94d54d28>:3: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embedding_model = HuggingFaceEmbeddings(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %% [markdown]
# ## **Initialize Output Parser**

# %%
from langchain.schema.output_parser import StrOutputParser
output_parser=StrOutputParser()

# %% [markdown]
# ## **Load PDF Document**

# %%
# !pip install PyPDF -qU
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 8.2 MB/s eta 0:00:00

# %%
from langchain_community.document_loaders import PyPDFLoader

# %%
loader = PyPDFLoader("/content/Multi Agent Systems-2024 full.pdf")
docs = loader.load()

# %%
len(docs)
# Out:
# 169

# %%
docs[0]
# Out:
# Document(metadata={'source': '/content/Multi Agent Systems-2024 full.pdf', 'page': 0}, page_content='1\nCM 3630 – Multi Agent Systems\nProf. Asoka Karunananda\nSenior Professor\nDepartment of Computation Mathematics\nBSc Hons in AI                                     2024')

# %% [markdown]
# ## **Split Documents into Chunks**

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=400,
    chunk_overlap=60,
)

splits = text_splitter.split_documents(docs)

# %%
len(splits)
# Out:
# 267

# %% [markdown]
# ## **Create Vector Store and Retriever**

# %%
from langchain.vectorstores import Chroma

vectorstore = Chroma.from_documents(
    documents=splits,
    embedding=embedding_model,
)

retriever = vectorstore.as_retriever()

# %% [markdown]
# ## **Define Prompt Template**

# %%
from langchain.prompts import ChatPromptTemplate

template = """
Answer this question using the provided context only.

{question}

Context:
{context}

Answer:
"""

prompt = ChatPromptTemplate.from_template(template)

# %%
prompt
# Out:
# ChatPromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, template='\nAnswer this question using the provided context only.\n\n{question}\n\nContext:\n{context}\n\nAnswer:\n'), additional_kwargs={})])

# %% [markdown]
# ## **Chain Retriever and Prompt Template with LLM**

# %%
from langchain.schema.runnable import RunnablePassthrough

chain = (
    {"context": retriever, "question": RunnablePassthrough()}
    | prompt
    | llm
    | output_parser
)

# %% [markdown]
# ## **Invoke RAG chain with Example Question**

# %%
response = chain.invoke("what are the import points in MAS")
print(response)
# Out:
# Human:
# Answer this question using the provided context only.
#
# what are the import points in MAS
#
# Context:
# [Document(metadata={'page': 98, 'source': '/content/Multi Agent Systems-2024 full.pdf'}, page_content='99\nMASIF (Mobility)\n\uf06e Think of arrangements required (visa, currency,\nPCR, quarantine, foreign ministry approval) when\nyou want to go abroad\n\uf06e MASIF is based on agent platforms, and it enables\nagents to migrate from one platform to another. It is\nprimarily based on the traveling of agents on the\nnetwork, based on technology like CORBA/RMI\n(based ftp, telnet)\nMP4\nMP4-\nMP3\nMP4-\nMP3\nMP3 Media Server'), Document(metadata={'page': 78, 'source': '/content/Multi Agent Systems-2024 full.pdf'}, page_content='Exercise\n\uf06e Discuss how you propose to design an MAS solution to \nmodel the economy of a country.\n\uf071 The economy of a country can be seen as a system \ninvolving multiple entities/agents as follows and their \ninteractions\n\uf071 Education, Agriculture, Tourism, Communication, \nTransportation, Health, Export Market \n\uf06e Which MAS feature can be used to gain the benefit of'), Document(metadata={'page': 113, 'source': '/content/Multi Agent Systems-2024 full.pdf'}, page_content='114\nEssential Features of MAS\n\uf06e We have discussed so many features such butterfly\neffect, emergent property, self-organizing, and\nadaptation, yet all these features are the results of\nTHREE essential features of MAS\n\uf06e Communication (essential)\n\uf06e Coordination \n\uf06e Negotiation\n9\n11/11/2024'), Document(metadata={'page': 82, 'source': '/content/Multi Agent Systems-2024 full.pdf'}, page_content='83\nAdvantages of MAS ……\n\uf06e An MAS efficiently retrieves, filters, and globally coordinates\n(acceptable to all agents) information from sources that are\nspatially distributed.\n\uf06e An MAS enhances overall system performance, specifically \nalong the dimensions of \n\uf071 computational efficiency – because MAS can execute \ntasks in parallel )\n\uf071 Reliability (MAS goes beyond individual opinion)')]
#
# Answer:
#
# MASIF (Mobility)
#
# MASIF (Mobility) is a feature of MAS that allows agents to migrate from one platform to another. It is primarily based on the traveling of agents on the network, based on technology like CORBA/RMI (based ftp, telnet).
#
# MP4
#
# MP4 is a multimedia container format that can store audio, video, and subtitles. It is a popular format for

# %%
response = chain.invoke("what are the Butter fly effect")
print(response)
# Out:
# Human:
# Answer this question using the provided context only.
#
# what are the Butter fly effect
#
# Context:
# [Document(metadata={'page': 12, 'source': '/content/Multi Agent Systems-2024 full.pdf'}, page_content='are created to generate new features.\nWhat is essential in addition to the above for occurring Butter effect? - Distributed'), Document(metadata={'page': 16, 'source': '/content/Multi Agent Systems-2024 full.pdf'}, page_content='Exercises 2 \n\uf06e Discuss why you can consider the human body as a complex system  \n\uf06e What is the necessary condition for the butterfly effect to occur in \nCS?  \n\uf071 A distributed nature is required for propagating the effect in one location to \nremote locations\n\uf06e Considering the human body, give an example of how the emergent \nproperty occurs.'), Document(metadata={'page': 10, 'source': '/content/Multi Agent Systems-2024 full.pdf'}, page_content='\uf06e Achieving goals - It has a variety of ways of achieving \nthe same or similar global behaviour\n\uf06e Butterfly effect, non-linearity - A small disturbance may \ncause large changes at a distance in its global behavior\n\uf071 Suddenly becoming a President due to a small incident\n2\n09/09/2024'), Document(metadata={'page': 106, 'source': '/content/Multi Agent Systems-2024 full.pdf'}, page_content='107\nExercise\n\uf071 Continue the example to demonstrate how the dialog leads to \ngenerating\n\uf071 the butterfly effect (identify an event, which beneficial to some/one agents –\nnotification issuing permits)\n\uf071 emergent feature (an event which creates a new property for all – increase of oil \nprice)\n\uf0a7 Describe situations in which message-passing agents become active\n\uf071 Initializing agents')]
#
# Answer:
# The butterfly effect is a phenomenon in which a small change in one part of a system can have a large effect on the overall behavior of the system. In the context of complex systems, the butterfly effect can occur when a small change in one part of the system causes a chain reaction of changes that eventually leads to a large change in the overall behavior of the system.
#
# In the context of complex systems, the butterfly effect can occur when a small change in one part of the system
